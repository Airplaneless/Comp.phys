# %%
from random import random
from math import sqrt
from math import pi
from math import log
import matplotlib.pylab as plt
from tqdm import tqdm

# %%
def guess(n, under_func):
    nc = 0.0
    for i in range(n):
        y, x = random(), random()
        if under_func(x, y):
            nc+=1
    return nc/n

# %%
def guess2(n, func):
    integ = 0.0
    for i in range(n):
        x = random()
        integ += func(x)
    return integ/n

# %%
def func(x):
    return sqrt(1-x**2)

# %%
def under_func(x, y):
    if y <= func(x):
        return True
    else:
        return False

# %%
guess(10000, under_func)*4
# Out:
# 3.1644

# %%
guess2(10000, func)*4
# Out:
# 3.1411199922250717

# %% [markdown]
# ### 1. Метод проб и ошибок Монте-Карло

# %%
x = list()
y = list()
for i in tqdm(range(1, 10000)):
    x.append(log(i))
    y.append(abs(guess(i, under_func)*4 - pi))
# Out:
# 100%|██████████| 9999/9999 [00:46<00:00, 213.12it/s]

# %%
plt.plot(x, y)
plt.xlabel('number of experiments, log')
plt.ylabel('error')
plt.title(u'Зависимость погрешности от числа испытаний')
plt.show()

# %% [markdown]
# ### 2. Метод Монте-Карло выборочного среднего

# %%
x = list()
y = list()
for i in tqdm(range(1, 10000)):
    x.append(log(i))
    y.append(abs(guess2(i, func)*4 - pi))
# Out:
# 100%|██████████| 9999/9999 [00:31<00:00, 317.80it/s]

# %%
plt.plot(x, y)
plt.xlabel('number of experiments, log')
plt.ylabel('error')
plt.title(u'Зависимость погрешности от числа испытаний')
plt.show()
