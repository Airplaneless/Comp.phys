# %%
import matplotlib.pylab as plt
import matplotlib.animation as animation
from Models import *
# %matplotlib notebook

# %%
lattice = SpinLattice.build3d_random(20, 20)
runner = SimulationRunner(model='Hberg', temperature=2.0, magnetic_field=None, epoch=1000)
results = runner.run(lattice, verbose=True)
# Out:
# Running: 100%|██████████| 1000/1000 [00:22<00:00, 45.18it/s]

# %%
spin_struct = SimulationRunner.spin_structure(results, 'xy')
# Out:
# Evaluate spin structure: 100%|██████████| 1000/1000 [1:32:01<00:00,  5.52s/it]

# %%
plt.imshow(spin_struct)
# Out:
# <img src="data:image/png;base64,..." width="640">
