# %%
# %matplotlib inline
from Models import *

# %%
lattice = SpinLattice.build3d_random(6, 6)
runner = SimulationRunner(model='Hberg', temperature=2.1, magnetic_field=[0.0, 0.0, 1.0], epoch=1000)
results = runner.run(lattice, verbose=True)
# Out:
# Running: 100%|██████████| 1000/1000 [00:02<00:00, 446.65it/s]

# %%
spin_struct_xy, spin_struct_z = SimulationRunner.spin_structure(results, (10, 10))
# Out:
# Evaluate spin structure:   0%|          | 0/1001 [00:00<?, ?it/s]Models.py:195: ComplexWarning: Casting complex values to real discards the imaginary part
#   structure_xy[I][J] = xsum ** 2 + ysum ** 2
# Models.py:196: ComplexWarning: Casting complex values to real discards the imaginary part
#   structure_z[I][J] = zsum ** 2
# Evaluate spin structure: 100%|██████████| 1001/1001 [01:17<00:00, 12.95it/s]

# %%
plt.imshow(spin_struct_xy)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.imshow(spin_struct_z)
# Out:
# <img src="data:image/png;base64,..." width="640">
