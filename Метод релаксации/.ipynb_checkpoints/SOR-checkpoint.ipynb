# %%
from solver import *
import matplotlib.pylab as plt
# %matplotlib inline

# %%
f = lambda x,y: 0

# %%
mesh = make_mesh(0.1, 10)
bound, z = set_boundary(10, mesh)
init_val = eval_func(f, mesh)
init_val = init_val*z + bound
res = solve(1000, mesh, init_val)

# %%
im = plt.imshow(res)
plt.colorbar(im)

# %%
f = lambda x,y: (x**2+y**2)/50.0

mesh = make_mesh(0.1, 10)
bound, z = set_boundary(10, mesh)
init_val = eval_func(f, mesh)
init_val = init_val*z + bound
res = solve(1000, mesh, init_val)

im = plt.imshow(res)
plt.colorbar(im)

# %%
(4**2+4**2)/50.0
# Out:
# 0.64
