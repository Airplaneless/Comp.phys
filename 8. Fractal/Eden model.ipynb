# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from random import choice
from math import sqrt
from tqdm import tqdm

# %%
def grow(A, bounds):    
    p = choice(bounds)
    A[p[0]][p[1]] = 1.0
    
    for m in range(-1, 2):
        for n in range(-1, 2):
            if not set([p[0], p[1]]) & set([0, A.shape[0]-1, A.shape[1]-1]) and not A[p[0]+m][p[1]+n]:
                bounds.append([p[0]+m, p[1]+n])
    bounds.remove([p[0], p[1]])
    
    return A

# %% [markdown]
# ### Модель роста Эдена на решетке 60х60 при 5000 итерациях

# %%
A = np.zeros((60, 60))
bounds = list([[60/2, 60/2]])
for i in tqdm(range(10000)):
    A = grow(A, bounds)
    if i%100 == 0:
        print '{} iteration'.format(i)
        plt.imshow(A)
        plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 0 iteration
#   0%|          | 1/10000 [00:00<50:46,  3.28it/s]
# 100 iteration
#   1%|          | 101/10000 [00:00<35:20,  4.67it/s]
# 200 iteration
#   2%|▏         | 201/10000 [00:00<24:36,  6.64it/s]
# 300 iteration
#   3%|▎         | 301/10000 [00:01<17:10,  9.42it/s]
# 400 iteration
#   4%|▍         | 401/10000 [00:01<12:00, 13.32it/s]
# 500 iteration
#   5%|▌         | 501/10000 [00:01<08:26, 18.76it/s]
# 600 iteration
#   6%|▌         | 601/10000 [00:01<05:57, 26.29it/s]
# 700 iteration
#   7%|▋         | 701/10000 [00:02<04:16, 36.26it/s]
# 800 iteration
#   8%|▊         | 801/10000 [00:02<03:03, 50.06it/s]
# 900 iteration
#   9%|▉         | 901/10000 [00:02<02:13, 67.99it/s]
# 1000 iteration
#  10%|█         | 1001/10000 [00:02<01:38, 91.33it/s]
# 1100 iteration
#  11%|█         | 1101/10000 [00:03<01:14, 120.25it/s]
# 1200 iteration
#  12%|█▏        | 1201/10000 [00:03<00:57, 153.90it/s]
# 1300 iteration
# ...

# %%
def mass(A, pc, radius):
    m = A[pc[0]][pc[1]]
    for i in xrange(len(A)):
        for j in xrange(len(A[i])):
            p = np.array([i, j])
            r = np.linalg.norm(p - pc)
            if r<radius:
                m+=A[p[0]][p[1]]
    return m

# %% [markdown]
# ## Оценка фрактальной размерности

# %%
x = np.arange(1, 30)
y = [mass(A, np.array([30, 30]), r) for r in x]

regr = LinearRegression()
regr.fit(np.log(x).reshape(-1,1), np.log(y))
print 'df = {}'.format(regr.coef_)

plt.plot(np.log(x), np.log(y), 'go')
plt.plot(np.log(x), regr.predict(np.log(x).reshape(-1,1)), 'r')
plt.xlabel('lg(r)')
plt.ylabel('lg(M)')
plt.title(u"График зависимости lnM от lnr")
plt.show()
# Out:
# df = [ 2.08347231]
